# %% [markdown]
# <a href="https://colab.research.google.com/github/beamingnp/ICD-Pregnancy.oi/blob/main/ichi%20browser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install flask -q
# !pip install sentence-transformers -q
# !pip install scikit-learn -q
# !npm install -g localtunnel
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹
# changed 22 packages in 4s
# ⠹
# ⠹3 packages are looking for funding
# ⠹  run `npm fund` for details
# ⠹

# %%
import os

os.makedirs("templates", exist_ok=True)

html = """
<!DOCTYPE html>
<html lang="fa" dir="rtl">

<head>

<meta charset="UTF-8">

<title>AI Medical Search</title>

<style>

body{
font-family:tahoma;
background:#f2f2f2;
padding:40px;
}

.container{
background:white;
padding:30px;
border-radius:10px;
max-width:800px;
margin:auto;
box-shadow:0 0 10px rgba(0,0,0,0.1);
}

input{
width:75%;
padding:12px;
font-size:18px;
}

button{
padding:12px 20px;
background:#007bff;
color:white;
border:none;
border-radius:6px;
cursor:pointer;
}

.result{
margin-top:20px;
padding:15px;
background:#eef;
border-radius:8px;
}

</style>

</head>

<body>

<div class="container">

<h2>جستجوی هوشمند کدهای گوش</h2>

<form method="POST">

<input
type="text"
name="symptoms"
placeholder="مثلاً: عمل پرده گوش یا تست شنوایی"
required
>

<button type="submit">جستجو</button>

</form>

{% if results %}

<h3>نتایج:</h3>

{% for r in results %}

<div class="result">

<p><b>کد:</b> {{ r.data.code }}</p>

<p><b>عنوان:</b> {{ r.data.title }}</p>

<p><b>دسته:</b> {{ r.data.category }}</p>

<p><b>امتیاز شباهت:</b> {{ r.score }}</p>

</div>

{% endfor %}

{% endif %}

</div>

</body>
</html>
"""

with open("templates/index.html","w",encoding="utf-8") as f:
    f.write(html)

print("✅ HTML created")
# Out:
# ✅ HTML created

# %%
import json

# دیتابیس جدید شما
new_database = {
  "ear_codes": [
    {
      "code": "XA01U5",
      "title": "Ear",
      "category": "anatomy",
      "keywords": ["ear", "auditory system", "hearing organ"],
      "synonyms": ["گوش", "عضو شنوایی"]
    },
    {
      "code": "XA57R3",
      "title": "Inner Ear",
      "category": "anatomy",
      "keywords": ["inner ear", "cochlea", "vestibule", "semicircular canals"],
      "synonyms": ["گوش داخلی", "لابیرنت"]
    },
    {
      "code": "XA3MS6",
      "title": "Semicircular canals",
      "category": "anatomy",
      "keywords": ["semicircular canals", "balance", "vestibular system"],
      "synonyms": ["کانال‌های نیم‌دایره", "مجاری نیم‌دایره"]
    },
    {
      "code": "XA0JV0",
      "title": "Cochlea",
      "category": "anatomy",
      "keywords": ["cochlea", "hearing", "spiral organ"],
      "synonyms": ["حلزون گوش"]
    },
    {
      "code": "XA6ZY7",
      "title": "Internal acoustic meatus",
      "category": "anatomy",
      "keywords": ["internal acoustic meatus", "ear canal", "auditory meatus"],
      "synonyms": ["مجاری شنوایی داخلی"]
    },
    {
      "code": "XA0L54",
      "title": "Labyrinth",
      "category": "anatomy",
      "keywords": ["labyrinth", "inner ear", "vestibular system"],
      "synonyms": ["لابیرنت", "گوش داخلی"]
    },
    {
      "code": "XA44P4",
      "title": "Auditory vestibule",
      "category": "anatomy",
      "keywords": ["auditory vestibule", "vestibule", "balance"],
      "synonyms": ["دهلیز شنوایی"]
    },
    {
      "code": "XA0G74",
      "title": "Middle Ear",
      "category": "anatomy",
      "keywords": ["middle ear", "tympanic cavity", "ossicles"],
      "synonyms": ["گوش میانی"]
    },
    {
      "code": "XA7XY6",
      "title": "Eustachian tube",
      "category": "anatomy",
      "keywords": ["eustachian tube", "auditory tube", "pharyngotympanic tube"],
      "synonyms": ["شیپور استاش", "لوله استاش"]
    },
    {
      "code": "XA16S6",
      "title": "Oval window",
      "category": "anatomy",
      "keywords": ["oval window", "fenestra vestibuli"],
      "synonyms": ["پنجره بیضی", "پنجره دهلیزی"]
    },
    {
      "code": "XA9RH9",
      "title": "Mastoid antrum",
      "category": "anatomy",
      "keywords": ["mastoid antrum", "tympanic antrum", "ear"],
      "synonyms": ["غار ماستوئید", "حفره ماستوئید"]
    },
    {
      "code": "XA3KB2",
      "title": "Tympanic cavity",
      "category": "anatomy",
      "keywords": ["tympanic cavity", "middle ear", "eardrum"],
      "synonyms": ["حفره صماخی", "حفره گوش میانی"]
    },
    {
      "code": "XA3UT7",
      "title": "Connective and other soft tissues of middle ear",
      "category": "anatomy",
      "keywords": ["connective tissue", "middle ear", "soft tissue"],
      "synonyms": ["بافت‌های نرم گوش میانی", "بافت همبند گوش میانی"]
    },
    {
      "code": "XA6EQ1",
      "title": "Bones of middle ear",
      "category": "anatomy",
      "keywords": ["ossicles", "middle ear bones", "malleus", "incus", "stapes"],
      "synonyms": ["استخوانچه‌های گوش میانی", "استخوان‌های گوش"]
    },
    {
      "code": "XA4D04",
      "title": "Incus",
      "category": "anatomy",
      "keywords": ["incus", "anvil", "middle ear bone"],
      "synonyms": ["سندانی", "اینکوس"]
    },
    {
      "code": "XA5DS8",
      "title": "Malleus",
      "category": "anatomy",
      "keywords": ["malleus", "hammer", "middle ear bone"],
      "synonyms": ["چکشی", "مالئوس"]
    },
    {
      "code": "XA3WA4",
      "title": "Stapes",
      "category": "anatomy",
      "keywords": ["stapes", "stirrup", "middle ear bone"],
      "synonyms": ["رکابی", "استپس"]
    },
    {
      "code": "XA08X4",
      "title": "Tympanic membrane",
      "category": "anatomy",
      "keywords": ["tympanic membrane", "eardrum", "ear drum"],
      "synonyms": ["پرده صماخ", "پرده گوش"]
    },
    {
      "code": "XA6ZY6",
      "title": "External Ear",
      "category": "anatomy",
      "keywords": ["external ear", "auricle", "ear canal", "pinna"],
      "synonyms": ["گوش خارجی", "گوش ظاهری"]
    },
    {
      "code": "XA4E71",
      "title": "Pinna",
      "category": "anatomy",
      "keywords": ["pinna", "auricle", "ear flap"],
      "synonyms": ["لاله گوش", "گوشک"]
    },
    {
      "code": "XA6B58",
      "title": "Helix of pinna",
      "category": "anatomy",
      "keywords": ["helix", "pinna", "ear rim"],
      "synonyms": ["لبه گوش", "مارپیچ گوش"]
    },
    {
      "code": "XA9A86",
      "title": "Crus of helix",
      "category": "anatomy",
      "keywords": ["crus of helix", "helix crus", "ear"],
      "synonyms": ["پایه لبه گوش"]
    },
    {
      "code": "XA9M10",
      "title": "Apex of helix",
      "category": "anatomy",
      "keywords": ["apex of helix", "helix apex", "ear"],
      "synonyms": ["نوک لبه گوش"]
    },
    {
      "code": "XA7AB8",
      "title": "Spine of helix",
      "category": "anatomy",
      "keywords": ["spine of helix", "helix spine", "ear"],
      "synonyms": ["خار لبه گوش"]
    },
    {
      "code": "XA1BZ8",
      "title": "Tail of helix",
      "category": "anatomy",
      "keywords": ["tail of helix", "helix tail", "ear"],
      "synonyms": ["دم لبه گوش"]
    },
    {
      "code": "XA7V14",
      "title": "Antihelix",
      "category": "anatomy",
      "keywords": ["antihelix", "ear", "pinna"],
      "synonyms": ["پادمارپیچ گوش"]
    },
    {
      "code": "XA96Q7",
      "title": "Crura of antihelix",
      "category": "anatomy",
      "keywords": ["crura of antihelix", "antihelix crus", "ear"],
      "synonyms": ["پایه‌های پادمارپیچ"]
    },
    {
      "code": "XA5LW2",
      "title": "Scaphoid fossa of pinna",
      "category": "anatomy",
      "keywords": ["scaphoid fossa", "pinna", "ear"],
      "synonyms": ["حفره استخوانی لاله گوش"]
    },
    {
      "code": "XA8W55",
      "title": "Concha of pinna",
      "category": "anatomy",
      "keywords": ["concha", "pinna", "ear"],
      "synonyms": ["صدفی لاله گوش"]
    },
    {
      "code": "XA5KM5",
      "title": "Cymba conchae",
      "category": "anatomy",
      "keywords": ["cymba conchae", "concha", "ear"],
      "synonyms": ["قوس صدفی"]
    },
    {
      "code": "XA8D58",
      "title": "Conchal bowl of pinna",
      "category": "anatomy",
      "keywords": ["conchal bowl", "pinna", "ear"],
      "synonyms": ["کاسه صدفی لاله گوش"]
    },
    {
      "code": "XA3RC6",
      "title": "Triangular fossa of pinna",
      "category": "anatomy",
      "keywords": ["triangular fossa", "pinna", "ear"],
      "synonyms": ["حفره مثلثی لاله گوش"]
    },
    {
      "code": "XA2N71",
      "title": "Tragus of pinna",
      "category": "anatomy",
      "keywords": ["tragus", "pinna", "ear"],
      "synonyms": ["تراگوس", "برآمدگی جلوی گوش"]
    },
    {
      "code": "XA5VK5",
      "title": "Intertragic notch of pinna",
      "category": "anatomy",
      "keywords": ["intertragic notch", "pinna", "ear"],
      "synonyms": ["بریدگی بین تراگوس‌ها"]
    },
    {
      "code": "XA0TW7",
      "title": "Earlobe",
      "category": "anatomy",
      "keywords": ["earlobe", "lobule", "ear"],
      "synonyms": ["نرمه گوش"]
    },
    {
      "code": "XA7RR9",
      "title": "Antitragus of pinna",
      "category": "anatomy",
      "keywords": ["antitragus", "pinna", "ear"],
      "synonyms": ["پادتراگوس"]
    },
    {
      "code": "XA3S47",
      "title": "Posterior surface of pinna",
      "category": "anatomy",
      "keywords": ["posterior surface", "pinna", "ear"],
      "synonyms": ["سطح پشتی لاله گوش"]
    },
    {
      "code": "XA6NU1",
      "title": "Antihelical fossa",
      "category": "anatomy",
      "keywords": ["antihelical fossa", "pinna", "ear"],
      "synonyms": ["حفره پادمارپیچی"]
    },
    {
      "code": "XA6KW8",
      "title": "Eminence of concha",
      "category": "anatomy",
      "keywords": ["eminence of concha", "concha", "ear"],
      "synonyms": ["برجستگی صدفی"]
    },
    {
      "code": "XA0H47",
      "title": "Eminence of scapha",
      "category": "anatomy",
      "keywords": ["eminence of scapha", "scapha", "ear"],
      "synonyms": ["برجستگی حفره استخوانی"]
    },
    {
      "code": "XA8VK6",
      "title": "Eminence of triangular fossa",
      "category": "anatomy",
      "keywords": ["eminence of triangular fossa", "pinna", "ear"],
      "synonyms": ["برجستگی حفره مثلثی"]
    },
    {
      "code": "XA4DV9",
      "title": "Retroauricular sulcus",
      "category": "anatomy",
      "keywords": ["retroauricular sulcus", "postauricular", "ear"],
      "synonyms": ["شیار پشت گوش"]
    },
    {
      "code": "XA3UC1",
      "title": "External auditory canal",
      "category": "anatomy",
      "keywords": ["external auditory canal", "ear canal", "meatus"],
      "synonyms": ["مجاری شنوایی خارجی", "کانال گوش"]
    },
    {
      "code": "XA5GS5",
      "title": "External auditory meatus",
      "category": "anatomy",
      "keywords": ["external auditory meatus", "ear meatus", "canal"],
      "synonyms": ["دهانه مجاری شنوایی خارجی"]
    },
    {
      "code": "XA5K66",
      "title": "Ceruminal gland",
      "category": "anatomy",
      "keywords": ["ceruminal gland", "cerumen", "ear wax gland"],
      "synonyms": ["غده جرم‌گیر", "غده موم‌ساز"]
    },
    {
      "code": "XA9E26",
      "title": "Skin of auricle",
      "category": "anatomy",
      "keywords": ["skin of auricle", "ear skin", "auricular skin"],
      "synonyms": ["پوست لاله گوش"]
    },
    {
      "code": "CAA.AB.AH",
      "title": "Size measurement of external ear, not elsewhere classified",
      "category": "assessment",
      "keywords": ["measure external ear", "ear size", "auricle measurement"],
      "synonyms": ["اندازه‌گیری گوش خارجی", "اندازه لاله گوش"]
    },
    {
      "code": "CAA.AD.AA",
      "title": "Biopsy of external ear, not elsewhere classified",
      "category": "procedure",
      "keywords": ["biopsy ear", "external ear biopsy", "auricle biopsy"],
      "synonyms": ["بیوپسی گوش خارجی", "نمونه‌برداری گوش"]
    },
    {
      "code": "CAA.DK.AH",
      "title": "Dressing of external ear, not elsewhere classified",
      "category": "procedure",
      "keywords": ["dressing ear", "ear bandage", "auricle dressing"],
      "synonyms": ["پانسمان گوش خارجی"]
    },
    {
      "code": "CAA.FA.AA",
      "title": "Incision of external ear, not elsewhere classified",
      "category": "surgery",
      "keywords": ["incision ear", "ear cut", "auricle incision"],
      "synonyms": ["برش گوش خارجی", "شیاف گوش"]
    },
    {
      "code": "CAA.JB.AA",
      "title": "Drainage of external ear, not elsewhere classified",
      "category": "procedure",
      "keywords": ["drain ear", "ear drainage", "auricle drainage"],
      "synonyms": ["تخلیه گوش خارجی", "درناژ گوش"]
    },
    {
      "code": "CAA.JD.AA",
      "title": "Removal of foreign body external ear, not elsewhere classified",
      "category": "procedure",
      "keywords": ["foreign body ear", "remove object ear", "ear foreign body"],
      "synonyms": ["خارج کردن جسم خارجی از گوش", "جسم خارجی گوش"]
    },
    {
      "code": "CAA.JJ.AA",
      "title": "Partial excision of external ear, not elsewhere classified",
      "category": "surgery",
      "keywords": ["partial excision ear", "auricle removal", "ear resection"],
      "synonyms": ["برداشتن قسمتی از گوش خارجی"]
    },
    {
      "code": "CAA.ML.AA",
      "title": "Reconstruction of external ear, not elsewhere classified",
      "category": "surgery",
      "keywords": ["reconstruct ear", "ear reconstruction", "auricle repair"],
      "synonyms": ["بازسازی گوش خارجی", "ترمیم گوش"]
    },
    {
      "code": "CAC.AD.AA",
      "title": "Biopsy of auricle",
      "category": "procedure",
      "keywords": ["biopsy auricle", "ear biopsy", "pinna biopsy"],
      "synonyms": ["بیوپسی لاله گوش"]
    },
    {
      "code": "CAC.FA.AA",
      "title": "Incision of auricle of ear",
      "category": "surgery",
      "keywords": ["incision auricle", "auricle cut", "pinna incision"],
      "synonyms": ["برش لاله گوش"]
    },
    {
      "code": "CAC.GA.AA",
      "title": "Destruction of auricle of ear",
      "category": "surgery",
      "keywords": ["destroy auricle", "ablation auricle", "ear destruction"],
      "synonyms": ["تخریب لاله گوش"]
    },
    {
      "code": "CAC.JB.AA",
      "title": "Drainage of auricle",
      "category": "procedure",
      "keywords": ["drain auricle", "auricle drainage", "pinna drainage"],
      "synonyms": ["تخلیه لاله گوش"]
    },
    {
      "code": "CAC.JD.AA",
      "title": "Removal of internal device or foreign body of auricle",
      "category": "procedure",
      "keywords": ["remove device auricle", "foreign body auricle", "auricle removal"],
      "synonyms": ["خارج کردن جسم یا دستگاه از لاله گوش"]
    },
    {
      "code": "CAC.JG.AC",
      "title": "Debridement of auricle of ear",
      "category": "procedure",
      "keywords": ["debridement auricle", "auricle cleaning", "ear debridement"],
      "synonyms": ["دبریدمان لاله گوش"]
    },
    {
      "code": "CAC.JI.AA",
      "title": "Local excision of lesion of auricle of ear",
      "category": "surgery",
      "keywords": ["excise lesion auricle", "remove growth ear", "auricle lesion excision"],
      "synonyms": ["برداشتن ضایعه موضعی لاله گوش"]
    },
    {
      "code": "CAC.JJ.AA",
      "title": "Partial excision of auricle of ear",
      "category": "surgery",
      "keywords": ["partial excision auricle", "partially remove ear", "auricle resection"],
      "synonyms": ["برداشتن قسمتی از لاله گوش"]
    },
    {
      "code": "CAC.JK.AA",
      "title": "Total excision of auricle of ear",
      "category": "surgery",
      "keywords": ["total excision auricle", "remove whole ear", "auricle removal"],
      "synonyms": ["برداشتن کامل لاله گوش"]
    },
    {
      "code": "CAC.JL.AA",
      "title": "Radical excision of auricle of ear",
      "category": "surgery",
      "keywords": ["radical excision auricle", "extensive ear removal", "auricle resection"],
      "synonyms": ["برداشتن رادیکال لاله گوش"]
    },
    {
      "code": "CAC.LB.AA",
      "title": "Reattachment of auricle",
      "category": "surgery",
      "keywords": ["reattach auricle", "auricle reattachment", "ear reattachment"],
      "synonyms": ["چسباندن مجدد لاله گوش"]
    },
    {
      "code": "CAC.LC.AH",
      "title": "Application of splint to auricle of ear",
      "category": "procedure",
      "keywords": ["splint auricle", "ear splint", "auricle support"],
      "synonyms": ["آتل بستن لاله گوش"]
    },
    {
      "code": "CAC.LJ.AA",
      "title": "Transfer of auricle of ear",
      "category": "surgery",
      "keywords": ["transfer auricle", "auricle flap", "ear transplant"],
      "synonyms": ["انتقال لاله گوش"]
    },
    {
      "code": "CAC.MK.AA",
      "title": "Repair of external ear",
      "category": "surgery",
      "keywords": ["repair ear", "ear repair", "auricle repair"],
      "synonyms": ["ترمیم گوش خارجی"]
    },
    {
      "code": "CAC.ML.AA",
      "title": "Reconstruction of auricle of ear",
      "category": "surgery",
      "keywords": ["reconstruct auricle", "auricle reconstruction", "ear rebuild"],
      "synonyms": ["بازسازی لاله گوش"]
    },
    {
      "code": "CAE.AD.AA",
      "title": "Biopsy of external auditory canal",
      "category": "procedure",
      "keywords": ["biopsy ear canal", "canal biopsy", "external meatus biopsy"],
      "synonyms": ["بیوپسی مجاری شنوایی خارجی"]
    },
    {
      "code": "CAE.DK.AC",
      "title": "Packing of external auditory canal",
      "category": "procedure",
      "keywords": ["pack ear canal", "ear packing", "meatus pack"],
      "synonyms": ["پک کردن مجاری شنوایی خارجی"]
    },
    {
      "code": "CAE.FA.AC",
      "title": "Incision of external auditory canal",
      "category": "surgery",
      "keywords": ["incise ear canal", "canal incision", "meatus cut"],
      "synonyms": ["برش مجاری شنوایی خارجی"]
    },
    {
      "code": "CAE.JA.AC",
      "title": "Irrigation of external auditory canal",
      "category": "procedure",
      "keywords": ["irrigate ear canal", "ear wash", "canal flushing"],
      "synonyms": ["شستشوی مجاری شنوایی خارجی"]
    },
    {
      "code": "CAE.JD.AC",
      "title": "Removal of internal device or foreign body from external auditory canal",
      "category": "procedure",
      "keywords": ["foreign body ear", "remove object ear", "ear canal foreign body", "remove insect ear", "ear foreign body removal"],
      "synonyms": ["جسم خارجی گوش", "خارج کردن جسم از گوش", "foreign object ear", "ear obstruction removal"]
    },
    {
      "code": "CAE.JI.AC",
      "title": "Local excision of lesion of external auditory canal",
      "category": "surgery",
      "keywords": ["excise canal lesion", "remove growth ear canal", "canal lesion excision"],
      "synonyms": ["برداشتن ضایعه مجاری شنوایی خارجی"]
    },
    {
      "code": "CAE.ML.AA",
      "title": "Reconstruction of external auditory canal",
      "category": "surgery",
      "keywords": ["reconstruct ear canal", "canal reconstruction", "meatus repair"],
      "synonyms": ["بازسازی مجاری شنوایی خارجی"]
    },
    {
      "code": "CBA.DN.AC",
      "title": "Implantation of internal device in middle ear, not elsewhere classified",
      "category": "surgery",
      "keywords": ["implant middle ear", "ear device implant", "BAHA implant"],
      "synonyms": ["کاشت دستگاه در گوش میانی", "کاشت سیستم شنوایی متصل به استخوان"]
    },
    {
      "code": "CBB.FA.AC",
      "title": "Myringotomy",
      "category": "surgery",
      "keywords": ["myringotomy", "tympanostomy", "ear tube", "drain ear", "incise eardrum"],
      "synonyms": ["میرینگوتومی", "برش پرده گوش", "لوله گذاری گوش"]
    },
    {
      "code": "CBB.JB.AC",
      "title": "Myringotomy with insertion of tube",
      "category": "surgery",
      "keywords": ["myringotomy tube", "ear tube insertion", "tympanostomy tube", "grommet insertion"],
      "synonyms": ["میرینگوتومی با لوله", "لوله گذاری پرده گوش", "گروماست"]
    },
    {
      "code": "CBB.MK.AC",
      "title": "Myringoplasty",
      "category": "surgery",
      "keywords": ["myringoplasty", "eardrum repair", "tympanic membrane repair", "patch eardrum"],
      "synonyms": ["میرینگوپلاستی", "ترمیم پرده گوش"]
    },
    {
      "code": "CBB.ML.AC",
      "title": "Reconstruction of tympanic membrane",
      "category": "surgery",
      "keywords": ["tympanic membrane reconstruction", "ear drum rebuild", "tympanoplasty"],
      "synonyms": ["بازسازی پرده گوش", "تیمپانوپلاستی"]
    },
    {
      "code": "CBF.FA.AC",
      "title": "Stapedotomy",
      "category": "surgery",
      "keywords": ["stapedotomy", "stapes surgery", "ear bone surgery"],
      "synonyms": ["استاپدوتومی", "جراحی رکابی"]
    },
    {
      "code": "CBF.JJ.AC",
      "title": "Stapedectomy",
      "category": "surgery",
      "keywords": ["stapedectomy", "remove stapes", "ear bone removal"],
      "synonyms": ["استاپدکتومی", "برداشتن رکابی"]
    },
    {
      "code": "CBF.ML.AC",
      "title": "Ossicular chain reconstruction",
      "category": "surgery",
      "keywords": ["ossicular reconstruction", "ear bone repair", "middle ear bone reconstruction"],
      "synonyms": ["بازسازی زنجیره استخوانچه‌های گوش"]
    },
    {
      "code": "CCB.DN.AA",
      "title": "Implantation of cochlear prosthetic device",
      "category": "surgery",
      "keywords": ["cochlear implant", "ear implant", "hearing implant", "cochlear device"],
      "synonyms": ["کاشت حلزون مصنوعی", "ایمپلنت حلزون"]
    },
    {
      "code": "CCB.JD.AA",
      "title": "Removal of cochlear prosthetic device",
      "category": "surgery",
      "keywords": ["remove cochlear implant", "cochlear device removal", "explant"],
      "synonyms": ["برداشتن ایمپلنت حلزون", "خارج کردن دستگاه حلزون"]
    },
    {
      "code": "CCB.KA.AA",
      "title": "Replacement of cochlear prosthetic device",
      "category": "surgery",
      "keywords": ["replace cochlear implant", "cochlear device replacement", "reimplantation"],
      "synonyms": ["تعویض ایمپلنت حلزون", "جایگزینی دستگاه حلزون"]
    },
    {
      "code": "CDA.JJ.AC",
      "title": "Partial mastoidectomy",
      "category": "surgery",
      "keywords": ["mastoidectomy", "mastoid surgery", "mastoid removal", "partial mastoid"],
      "synonyms": ["ماستوئیدکتومی نسبی", "جراحی ماستوئید"]
    },
    {
      "code": "CDA.JK.AC",
      "title": "Total mastoidectomy",
      "category": "surgery",
      "keywords": ["total mastoidectomy", "complete mastoid removal", "mastoid surgery"],
      "synonyms": ["ماستوئیدکتومی کامل"]
    },
    {
      "code": "CDA.JL.AC",
      "title": "Radical mastoidectomy",
      "category": "surgery",
      "keywords": ["radical mastoidectomy", "extensive mastoid surgery", "mastoid cavity"],
      "synonyms": ["ماستوئیدکتومی رادیکال"]
    },
    {
      "code": "CTB.AB.ZZ",
      "title": "Audiometry",
      "category": "assessment",
      "keywords": ["audiometry", "hearing test", "pure tone", "speech audiometry"],
      "synonyms": ["ادیومتری", "شنوایی‌سنجی", "تست شنوایی"]
    },
    {
      "code": "CTB.AF.ZZ",
      "title": "Auditory evoked potentials",
      "category": "assessment",
      "keywords": ["auditory evoked potentials", "AEP", "brainstem response", "ABR", "BERA"],
      "synonyms": ["پتانسیل‌های برانگیخته شنوایی", "ABR", "BERA"]
    },
    {
      "code": "CTE.AC.ZZ",
      "title": "Test of vestibular functions",
      "category": "assessment",
      "keywords": ["vestibular test", "balance test", "caloric test", "ENG", "VNG"],
      "synonyms": ["آزمایش عملکرد دهلیزی", "تست تعادل"]
    },
    {
      "code": "XG2MH3",
      "title": "Number of anatomical structures an intervention is performed on",
      "category": "quantifier",
      "keywords": ["number of structures", "anatomical count", "how many organs"],
      "synonyms": ["تعداد ساختارهای آناتومیک", "تعداد اندام‌های درگیر"]
    },
    {
      "code": "XG90G8",
      "title": "Two anatomical structures an intervention is performed on",
      "category": "quantifier",
      "keywords": ["two structures", "two organs", "bilateral"],
      "synonyms": ["دو ساختار", "دو طرفه"]
    },
    {
      "code": "XG0TH4",
      "title": "Three anatomical structures an intervention is performed on",
      "category": "quantifier",
      "keywords": ["three structures", "three organs"],
      "synonyms": ["سه ساختار"]
    },
    {
      "code": "XG8WV4",
      "title": "Four anatomical structures an intervention is performed on",
      "category": "quantifier",
      "keywords": ["four structures", "four organs"],
      "synonyms": ["چهار ساختار"]
    },
    {
      "code": "XG95C9",
      "title": "Five anatomical structures an intervention is performed on",
      "category": "quantifier",
      "keywords": ["five structures", "five organs"],
      "synonyms": ["پنج ساختار"]
    },
    {
      "code": "XG8E68",
      "title": "Six anatomical structures an intervention is performed on",
      "category": "quantifier",
      "keywords": ["six structures", "six organs"],
      "synonyms": ["شش ساختار"]
    },
    {
      "code": "XG6P84",
      "title": "Seven anatomical structures an intervention is performed on",
      "category": "quantifier",
      "keywords": ["seven structures", "seven organs"],
      "synonyms": ["هفت ساختار"]
    },
    {
      "code": "XG8UX1",
      "title": "Eight anatomical structures an intervention is performed on",
      "category": "quantifier",
      "keywords": ["eight structures", "eight organs"],
      "synonyms": ["هشت ساختار"]
    },
    {
      "code": "XG4BS1",
      "title": "Nine anatomical structures an intervention is performed on",
      "category": "quantifier",
      "keywords": ["nine structures", "nine organs"],
      "synonyms": ["نه ساختار"]
    },
    {
      "code": "XG3BL0",
      "title": "Ten or more anatomical structures an intervention is performed on",
      "category": "quantifier",
      "keywords": ["ten or more structures", "multiple organs"],
      "synonyms": ["ده ساختار یا بیشتر"]
    },
    {
      "code": "XG3R70",
      "title": "Number of interventions performed",
      "category": "quantifier",
      "keywords": ["number of procedures", "intervention count", "how many times"],
      "synonyms": ["تعداد مداخلات انجام شده"]
    },
    {
      "code": "XG5D63",
      "title": "Two of the same interventions performed",
      "category": "quantifier",
      "keywords": ["two procedures", "double intervention", "repeat twice"],
      "synonyms": ["دو مداخله یکسان"]
    },
    {
      "code": "XG3H82",
      "title": "Three of the same intervention performed",
      "category": "quantifier",
      "keywords": ["three procedures", "repeat three times"],
      "synonyms": ["سه مداخله یکسان"]
    },
    {
      "code": "XG0XC6",
      "title": "Four of the same intervention performed",
      "category": "quantifier",
      "keywords": ["four procedures", "repeat four times"],
      "synonyms": ["چهار مداخله یکسان"]
    },
    {
      "code": "XG33A8",
      "title": "Five of the same intervention performed",
      "category": "quantifier",
      "keywords": ["five procedures", "repeat five times"],
      "synonyms": ["پنج مداخله یکسان"]
    },
    {
      "code": "XG4C28",
      "title": "Six of the same intervention performed",
      "category": "quantifier",
      "keywords": ["six procedures", "repeat six times"],
      "synonyms": ["شش مداخله یکسان"]
    },
    {
      "code": "XG8L61",
      "title": "Seven of the same intervention performed",
      "category": "quantifier",
      "keywords": ["seven procedures", "repeat seven times"],
      "synonyms": ["هفت مداخله یکسان"]
    },
    {
      "code": "XG0GY7",
      "title": "Eight of the same intervention performed",
      "category": "quantifier",
      "keywords": ["eight procedures", "repeat eight times"],
      "synonyms": ["هشت مداخله یکسان"]
    },
    {
      "code": "XG0RP7",
      "title": "Nine of the same intervention performed",
      "category": "quantifier",
      "keywords": ["nine procedures", "repeat nine times"],
      "synonyms": ["نه مداخله یکسان"]
    },
    {
      "code": "XG8Z24",
      "title": "Ten or more of the same intervention performed",
      "category": "quantifier",
      "keywords": ["ten or more procedures", "multiple repeats"],
      "synonyms": ["ده مداخله یکسان یا بیشتر"]
    },
    {
      "code": "XG5353",
      "title": "Number of therapeutic products inserted",
      "category": "quantifier",
      "keywords": ["number of implants", "how many devices", "product count"],
      "synonyms": ["تعداد محصولات درمانی کاشته شده"]
    },
    {
      "code": "XG2L64",
      "title": "Two therapeutic products inserted",
      "category": "quantifier",
      "keywords": ["two implants", "two devices", "double insertion"],
      "synonyms": ["دو محصول درمانی کاشته شده"]
    },
    {
      "code": "XG6DZ4",
      "title": "Three therapeutic products inserted",
      "category": "quantifier",
      "keywords": ["three implants", "three devices"],
      "synonyms": ["سه محصول درمانی کاشته شده"]
    },
    {
      "code": "XG6MH8",
      "title": "Four therapeutic products inserted",
      "category": "quantifier",
      "keywords": ["four implants", "four devices"],
      "synonyms": ["چهار محصول درمانی کاشته شده"]
    },
    {
      "code": "XG2404",
      "title": "Five therapeutic products inserted",
      "category": "quantifier",
      "keywords": ["five implants", "five devices"],
      "synonyms": ["پنج محصول درمانی کاشته شده"]
    },
    {
      "code": "XG9U80",
      "title": "Six therapeutic products inserted",
      "category": "quantifier",
      "keywords": ["six implants", "six devices"],
      "synonyms": ["شش محصول درمانی کاشته شده"]
    },
    {
      "code": "XG0ZT7",
      "title": "Seven therapeutic products inserted",
      "category": "quantifier",
      "keywords": ["seven implants", "seven devices"],
      "synonyms": ["هفت محصول درمانی کاشته شده"]
    },
    {
      "code": "XG8QN6",
      "title": "Eight therapeutic products inserted",
      "category": "quantifier",
      "keywords": ["eight implants", "eight devices"],
      "synonyms": ["هشت محصول درمانی کاشته شده"]
    },
    {
      "code": "XG77V0",
      "title": "Nine therapeutic products inserted",
      "category": "quantifier",
      "keywords": ["nine implants", "nine devices"],
      "synonyms": ["نه محصول درمانی کاشته شده"]
    },
    {
      "code": "XG5P61",
      "title": "Ten or more therapeutic products inserted",
      "category": "quantifier",
      "keywords": ["ten or more implants", "multiple devices"],
      "synonyms": ["ده محصول درمانی کاشته شده یا بیشتر"]
    }
  ]
}

# ذخیره کردن فایل با نام diseases.json
with open('diseases.json', 'w', encoding='utf-8') as f:
    json.dump(new_database, f, ensure_ascii=False, indent=4)

print("فایل جدید با موفقیت ذخیره شد!")
# Out:
# فایل جدید با موفقیت ذخیره شد!

# %%
import json
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# بارگذاری دیتابیس ICHI
with open("diseases.json","r",encoding="utf-8") as f:
    data=json.load(f)

codes=data["ear_codes"]

# مدل چندزبانه
model = SentenceTransformer("paraphrase-multilingual-MiniLM-L12-v2")

# متن هر کد برای embedding
texts=[
    item["title"]+" "+item["category"]+" "+" ".join(item.get("keywords",[]))
    for item in codes
]

embeddings=model.encode(texts)

def ichi_ai(query,top_k=5,threshold=0.45):

    q_emb=model.encode([query])
    sims=cosine_similarity(q_emb,embeddings)[0]

    results=[]

    for i,score in enumerate(sims):
        if score>=threshold:
            results.append({
                "code":codes[i]["code"],
                "title":codes[i]["title"],
                "category":codes[i]["category"],
                "score":float(score)
            })

    results=sorted(results,key=lambda x:x["score"],reverse=True)

    return results[:top_k]
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]

# %%
from flask import Flask, render_template, request
import json
import numpy as np
import threading
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# بارگذاری مجدد دیتابیس (مطمئن شو فایل diseases.json همان‌جاست)
with open("diseases.json", "r", encoding="utf-8") as f:
    data = json.load(f)

diseases = data["ear_codes"]

# مدل را دوباره تعریف می‌کنیم (اگر قبلاً در سلول دیگری تعریف شده، این بخش اختیاری است)
model = SentenceTransformer("paraphrase-multilingual-MiniLM-L12-v2")

# تولید Embeddingها (این بخش را طبق کدهای قبلی خودت نگه دار یا اینجا دوباره انجام بده)
texts = [" ".join([item["title"], item["category"], " ".join(item["keywords"]), " ".join(item["synonyms"])]) for item in diseases]
embeddings = model.encode(texts)
targets = {
    "ear": ["ear","outer ear","external ear"],
    "auricle": ["auricle","pinna"],
    "ear canal": ["ear canal","external auditory canal"],
    "middle ear": ["middle ear"],
    "tympanic membrane": ["tympanic membrane","eardrum"],
    "cochlea": ["cochlea"],
    "hearing": ["hearing","hearing function"]
}

actions = {
    "biopsy": ["biopsy","sample"],
    "incision": ["incision","cut"],
    "drainage": ["drainage","drain"],
    "repair": ["repair","fix","reconstruction"],
    "excision": ["excision","remove lesion"],
    "test": ["test","assessment","evaluation"],
    "implant": ["implant","device insertion"]
}

means = {
    "audiometry": ["audiometry","hearing test"],
    "endoscopic": ["endoscopic","endoscopy"],
    "surgical": ["surgery","operation"],
    "device": ["tube","prosthesis","implant"]
    action_filters = {
    "drainage": ["drainage","aspiration","myringotomy"],
    "incision": ["incision","otomy"],
    "excision": ["excision","resection","removal"],
    "repair": ["repair","reconstruction"],
    "implant": ["implant","insertion"],
    "test": ["assessment","test","audiometry","evaluation"]
}
action_filters = {
    "drainage": ["drainage","aspiration","myringotomy"],
    "incision": ["incision","otomy"],
    "excision": ["excision","resection","removal"],
    "repair": ["repair","reconstruction"],
    "implant": ["implant","insertion"],
    "test": ["assessment","test","audiometry","evaluation"]
}

}
def build_query(text):
def detect_action(text):

    text=text.lower()

    for action,words in action_filters.items():
        if any(w in text for w in words):
            return action

    return None

    text=text.lower()

    enhanced=text

    for key,words in targets.items():
        if any(w in text for w in words):
            enhanced+=" "+key

    for key,words in actions.items():
        if any(w in text for w in words):
            enhanced+=" "+key

    for key,words in means.items():
        if any(w in text for w in words):
            enhanced+=" "+key

    return enhanced

# --- تابع جستجوی هوشمند با فیلتر آستانه ---
def guess_code(query, threshold=0.45, top_k=5):
    query = build_query(query)
    detected_action = detect_action(query)
    query_embedding = model.encode([query])
    sims = cosine_similarity(query_embedding, embeddings)[0]

    # پیدا کردن ایندکس‌هایی که امتیازشان بالای 0.45 است
    # و مرتب‌سازی آن‌ها بر اساس امتیاز
    results=[]

for idx in top_indices:

    item=data[idx]
    score=float(similarities[idx])

    if score < threshold:
        continue

    title=item["title"].lower()

    # ✅ action filtering
    if detected_action:

        allowed_words=action_filters[detected_action]

        if not any(word in title for word in allowed_words):
            continue

    results.append({
        "code": item["code"],
        "title": item["title"],
        "score": round(score,3)
    })

app = Flask(__name__)

@app.route("/", methods=["GET", "POST"])
def home():
    results = None
    if request.method == "POST":
        text = request.form.get("symptoms")
        if text:
            # جستجو با فیلتر آستانه 0.45
            results = guess_code(text, threshold=0.45)
    return render_template("index.html", results=results)

# اجرای سرور
threading.Thread(
    target=app.run,
    kwargs={"host": "0.0.0.0", "port": 5010, "use_reloader": False}
).start()

print("✅ Flask updated and running on port 5010")
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# ✅ Flask updated and running on port 5010
#  * Serving Flask app '__main__'
#  * Debug mode: off
# Address already in use
# Port 5010 is in use by another program. Either identify and stop that program, or start the server with a different port.

# %%
# !lt --port 5010
# Out:
# your url is: https://curly-pianos-hammer.loca.lt
# INFO:werkzeug:127.0.0.1 - - [01/Jul/2026 15:48:18] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [01/Jul/2026 15:48:19] "GET /favicon.ico HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [01/Jul/2026 15:49:00] "POST / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [01/Jul/2026 15:51:13] "POST / HTTP/1.1" 200 -
